# %%
# Mount Google Drive
from google.colab import drive # import drive from google colab

ROOT = "/content/gdrive"     # default location for the drive
print(ROOT)                 # print content of ROOT (Optional)

drive.mount(ROOT)           # we mount the google drive at /content/drive

# %%
# !git push origin master

# %%
  # !git config --global user.email "rjayar4@uic.edu"
  # !git config --global user.name "rakshitharj"

# %%
# !git clone https://7519148727b530a7734e756bada859a5811db262@github.com/benza613/Sentiment-Analysis-using-Deep-Learning.git

# %%
# !git push origin master

# %%
#above frequently used commands

# %%
import os
import json
import gzip
import pandas as pd
from urllib.request import urlopen

# %%
#Extracting data from url
#!wget http://deepyeti.ucsd.edu/jianmo/amazon/sample/meta_Computers.json.gz
#!wget https://drive.google.com/drive/u/0/folders/1FJjwIPF2s1nutqhmbUZtm9N7fbCf2Kdz

# %%
#opening the json and reading data
data = []
with gzip.open('Appliances.json.gz') as f:
    for l in f:
        data.append(json.loads(l.strip()))
    
# total length of list, this number equals total number of products
print(len(data))

# first row of the list
print(data[1])

# %%
# convert list into pandas dataframe
df = pd.DataFrame.from_dict(data)

print(len(df))

# %%
#Check the column names
print(df.columns)

# %%
#clean the data
clean_df=df[['reviewerID','vote','reviewText']]
print(clean_df)

# %%
#store in csv
clean_df.to_csv(r'Appliances_review.csv', index = False)
